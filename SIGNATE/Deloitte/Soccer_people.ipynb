# %% [markdown]
# データ読み込み

# %%
import pandas as pd
import numpy as np

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %% [markdown]
# テストデータ結合

# %%
test_1 = pd.read_csv("20230616_0116.csv",names=['id', 'attendance'])

# %%
test_2 = test.copy()
first_column = test_1.pop('attendance')
l = len(test_2.columns.values)
test_2.insert(l,"attendance",first_column)

# %%
#train =pd.concat([train, test_2])

# %%
display(train.tail())
display(test.head())
# Out:
#          id  match_date kick_off_time section round home_team away_team  \
# 3361  18195  2016-11-03         13:33    第17節   第1日       川崎F       G大阪
# 3362  18196  2016-11-03         13:33    第17節   第1日        甲府        鳥栖
# 3363  18197  2016-11-03         13:33    第17節   第1日        新潟        広島
# 3364  18198  2016-11-03         13:33    第17節   第1日       名古屋        湘南
# 3365  18199  2016-11-03         13:33    第17節   第1日        福岡         柏
#
#                venue  weather  temperature  humidity  \
# 3361        等々力陸上競技場        晴         20.0        41
# 3362       山梨中銀スタジアム        晴         20.5        20
# 3363  デンカビッグスワンスタジアム  曇のち雨のち晴         18.2        33
# 3364      パロマ瑞穂スタジアム        晴         17.0        41
# 3365    レベルファイブスタジアム        晴         18.3        50
#
#                           broadcasters  attendance
# 3361      スカパー!/スカパー!プレミアムサービス/NHK BS1       25694
# 3362              スカパー!/スカパー!プレミアムサービス       14676
# 3363  スカパー!/スカパー!プレミアムサービス/NHK新潟/NHK広島       27081
# 3364       スカパー!/スカパー!プレミアムサービス/NHK名古屋       18474
# 3365              スカパー!/スカパー!プレミアムサービス       13042
#       id  match_date kick_off_time section round home_team away_team  \
# 0  19075  2017-02-25         12:35     第1節   第1日      横浜FM        浦和
# 1  19076  2017-02-25         14:04     第1節   第1日        仙台        札幌
# 2  19077  2017-02-25         14:04     第1節   第1日        鹿島      FC東京
# 3  19078  2017-02-25         14:04     第1節   第1日        清水        神戸
# 4  19079  2017-02-25         14:04     第1節   第1日        広島        新潟
#
#             venue weather  temperature  humidity        broadcasters
# 0         日産スタジアム       晴         10.2      45.0     DAZN/テレビ神奈川/テレ玉
# 1    ユアテックスタジアム仙台       曇         10.6      36.0    DAZN/NHK仙台/NHK札幌
# 2  県立カシマサッカースタジアム       晴         10.1      63.0          DAZN/NHK総合
# 3     IAIスタジアム日本平       晴         15.0      40.0  DAZN/NHK BS1/テレビ静岡
# 4    エディオンスタジアム広島       晴         11.2      45.0    DAZN/NHK広島/NHK新潟

# %%
sec_1 = list(set(train["round"].values.tolist()))
l =[]
for i in range(len(sec_1)):
    x = list(sec_1[i])
    x1 = sec_1[i].lstrip(x[0]).rstrip(x[len(x)-1])
    l.append(int(x1))
sec_1 = sorted(l)
print(sec_1)
# Out:
# [1, 2, 3]

# %% [markdown]
# 日付・試合正規化

# %%
train["match_date"] = [int(x.replace("-","")) for x in train["match_date"].values]
train["kick_off_time"] = [int(x.replace(":","")) for x in train["kick_off_time"].values]
train["section"] = [int(x.replace("第","").replace("節","")) for x in train["section"].values]
train["round"] = [int(x.replace("第","").replace("日","")) for x in train["round"].values]
train.head()
# Out:
#      id  match_date  kick_off_time  section  round home_team away_team  \
# 0  9190    20060304           1604        1      1       G大阪        浦和
# 1  9191    20060305           1300        1      2        甲府        清水
# 2  9192    20060305           1335        1      2      FC東京        大分
# 3  9193    20060305           1404        1      2        磐田        福岡
# 4  9194    20060305           1404        1      2       名古屋       C大阪
#
#               venue weather  temperature  humidity  \
# 0           万博記念競技場       晴          8.3        40
# 1  山梨県小瀬スポーツ公園陸上競技場       晴         12.9        28
# 2          味の素スタジアム       晴         12.1        35
# 3        静岡スタジアムエコパ       晴         11.6        42
# 4       名古屋市瑞穂陸上競技場       晴         13.1        32
#
#                                  broadcasters  attendance
# 0                           NHK総合/J SPORTS(録)       20916
# 1                   山梨放送/テレビ静岡(録)/J SPORTS(録)       14277
# 2                   BS-i/MXテレビ(録)/J SPORTS(録)       22531
# 3                                    J SPORTS       28564
# 4  スカイパーフェクTV!/NHK名古屋(録)/NHK大阪(録)/J SPORTS(録)       17199

# %% [markdown]
# チーム名

# %%
home_team_key = sorted(set(train["home_team"].values.tolist()),key =train["home_team"].values.tolist().index)
sum(train["attendance"][train["home_team"] == home_team_key[0]].values)/len(train["attendance"][train["home_team"] == home_team_key[0]].values)
l =[]
a = []
for i in range(len(home_team_key)):
    ave = sum(train["attendance"][train["home_team"] == home_team_key[i]].values)/len(train["attendance"][train["home_team"] == home_team_key[i]].values)
    l.append(ave)
    a.append(ave)
a.sort()
home_t =[0]*len(l)
for i in range(len(l)):
    home_t[i] = a.index(l[i])

for i in range(len(l)):
    train["home_team"][train["home_team"] == home_team_key[i]] = int(home_t[i])
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/4210563304.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["home_team"][train["home_team"] == home_team_key[i]] = int(home_t[i])

# %% [markdown]
# 天気

# %%
for i in range(len(l)):
    train["away_team"][train["away_team"] == home_team_key[i]] = int(home_t[i])
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/3558276539.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["away_team"][train["away_team"] == home_team_key[i]] = int(home_t[i])

# %%
weather_key = sorted(set(train["weather"].values.tolist()),key =train["weather"].values.tolist().index)
sum(train["attendance"][train["weather"] == weather_key[0]].values)/len(train["attendance"][train["weather"] == weather_key[0]].values)
l =[]
a = []
for i in range(len(weather_key)):
    ave = sum(train["attendance"][train["weather"] == weather_key[i]].values)/len(train["attendance"][train["weather"] == weather_key[i]].values)
    l.append(ave)
    a.append(ave)
a.sort()
weather_t =[0]*len(l)
for i in range(len(l)):
    weather_t[i] = a.index(l[i])

for i in range(len(l)):
    train["weather"][train["weather"] == weather_key[i]] = int(weather_t[i])
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/310363291.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["weather"][train["weather"] == weather_key[i]] = int(weather_t[i])

# %% [markdown]
# 会場情報追加

# %%
venue_info = pd.read_csv("venue_information.csv")

# %%
venue_info.head()
# Out:
#               venue  capacity           address
# 0           万博記念競技場     21000   大阪府吹田市千里万博公園5-2
# 1  山梨県小瀬スポーツ公園陸上競技場     15859      山梨県甲府市小瀬町840
# 2          味の素スタジアム     48999     東京都調布市西町376-3
# 3        静岡スタジアムエコパ     51697    静岡県袋井市愛野2300−1
# 4       名古屋市瑞穂陸上競技場     20223  愛知県名古屋市瑞穂区山下通5-1

# %%
l =venue_info["address"].values

# %%
import re
DATA = """
北海道
青森県
岩手県
宮城県
秋田県
山形県
福島県
茨城県
栃木県
群馬県
埼玉県
千葉県
東京都
神奈川県
新潟県
富山県
石川県
福井県
山梨県
長野県
岐阜県
静岡県
愛知県
三重県
滋賀県
京都府
大阪府
兵庫県
奈良県
和歌山県
鳥取県
島根県
岡山県
広島県
山口県
徳島県
香川県
愛媛県
高知県
福岡県
佐賀県
長崎県
熊本県
大分県
宮崎県
鹿児島県
沖縄県
"""

prefecture = re.findall(r'(\w+)\n',DATA)
print(prefecture)
# Out:
# ['北海道', '青森県', '岩手県', '宮城県', '秋田県', '山形県', '福島県', '茨城県', '栃木県', '群馬県', '埼玉県', '千葉県', '東京都', '神奈川県', '新潟県', '富山県', '石川県', '福井県', '山梨県', '長野県', '岐阜県', '静岡県', '愛知県', '三重県', '滋賀県', '京都府', '大阪府', '兵庫県', '奈良県', '和歌山県', '鳥取県', '島根県', '岡山県', '広島県', '山口県', '徳島県', '香川県', '愛媛県', '高知県', '福岡県', '佐賀県', '長崎県', '熊本県', '大分県', '宮崎県', '鹿児島県', '沖縄県']

# %%
for i in range(len(prefecture)):
    for j in range(len(l)):
        if prefecture[i] in venue_info["address"][j]:
            venue_info["address"][j]=prefecture[i]
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/3516695545.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   venue_info["address"][j]=prefecture[i]

# %%
venue_info_key = sorted(set(venue_info["venue"].values.tolist()),key =venue_info["venue"].values.tolist().index)
train["capacity"]=0
train["address"] =0
test["capacity"]=0
test["address"] =0
for i in range(len(venue_info_key)):
    train["capacity"][train["venue"]==venue_info_key[i]] = venue_info["capacity"][i]
    test["capacity"][test["venue"]==venue_info_key[i]] = venue_info["capacity"][i]
    train["address"][train["venue"]==venue_info_key[i]] = venue_info["address"][i]
    test["address"][test["venue"]==venue_info_key[i]] = venue_info["address"][i]
    
train.head()
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1157446046.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["capacity"][train["venue"]==venue_info_key[i]] = venue_info["capacity"][i]
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1157446046.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["capacity"][test["venue"]==venue_info_key[i]] = venue_info["capacity"][i]
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1157446046.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["address"][train["venue"]==venue_info_key[i]] = venue_info["address"][i]
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1157446046.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["address"][test["venue"]==venue_info_key[i]] = venue_info["address"][i]
#      id  match_date  kick_off_time  section  round home_team away_team  \
# 0  9190    20060304           1604        1      1        21        28
# 1  9191    20060305           1300        1      2         6        16
# 2  9192    20060305           1335        1      2        26        24
# 3  9193    20060305           1404        1      2        10         7
# 4  9194    20060305           1404        1      2        19        18
#
#               venue weather  temperature  humidity  \
# 0           万博記念競技場      29          8.3        40
# 1  山梨県小瀬スポーツ公園陸上競技場      29         12.9        28
# 2          味の素スタジアム      29         12.1        35
# 3        静岡スタジアムエコパ      29         11.6        42
# 4       名古屋市瑞穂陸上競技場      29         13.1        32
#
#                                  broadcasters  attendance  capacity address
# 0                           NHK総合/J SPORTS(録)       20916     21000     大阪府
# 1                   山梨放送/テレビ静岡(録)/J SPORTS(録)       14277     15859     山梨県
# 2                   BS-i/MXテレビ(録)/J SPORTS(録)       22531     48999     東京都
# 3                                    J SPORTS       28564     51697     静岡県
# 4  スカイパーフェクTV!/NHK名古屋(録)/NHK大阪(録)/J SPORTS(録)       17199     20223     愛知県

# %%
l =[]
a = []
for i in range(len(prefecture)):
    if len(train["attendance"][train["address"] == prefecture[i]].values) !=0:
        ave = sum(train["attendance"][train["address"] == prefecture[i]].values)/len(train["attendance"][train["address"] == prefecture[i]].values)
    l.append(ave)
    a.append(ave)
a.sort()
venue_i_t =[0]*len(l)
for i in range(len(l)):
    venue_i_t[i] = a.index(l[i])

for i in range(len(l)):
    train["address"][train["address"] == prefecture[i]] = int(venue_i_t[i])

# %%
venue_key = sorted(set(train["venue"].values.tolist()),key =train["venue"].values.tolist().index)
l =[]
a = []
for i in range(len(venue_key)):
    ave = sum(train["attendance"][train["venue"] == venue_key[i]].values)/len(train["attendance"][train["venue"] == venue_key[i]].values)
    l.append(ave)
    a.append(ave)
a.sort()
venue_t =[0]*len(l)
for i in range(len(l)):
    venue_t[i] = a.index(l[i])

for i in range(len(l)):
    train["venue"][train["venue"] == venue_key[i]] = int(venue_t[i])
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1743366145.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["venue"][train["venue"] == venue_key[i]] = int(venue_t[i])

# %% [markdown]
# 放送局

# %%
"""""
broadcasters_key = sorted(set(train["broadcasters"].values.tolist()),key =train["broadcasters"].values.tolist().index)
sum(train["attendance"][train["broadcasters"] == broadcasters_key[0]].values)/len(train["attendance"][train["broadcasters"] == broadcasters_key[0]].values)
l =[]
a = []
for i in range(len(broadcasters_key)):
    ave = sum(train["attendance"][train["broadcasters"] == broadcasters_key[i]].values)/len(train["attendance"][train["broadcasters"] == broadcasters_key[i]].values)
    l.append(ave)
    a.append(ave)
a.sort()
broad_t =[0]*len(l)
for i in range(len(l)):
    broad_t[i] = a.index(l[i])

for i in range(len(l)):
    train["broadcasters"][train["broadcasters"] == broadcasters_key[i]] = int(broad_t[i])
    
train.head()
"""
# Out:
# '""\nbroadcasters_key = sorted(set(train["broadcasters"].values.tolist()),key =train["broadcasters"].values.tolist().index)\nsum(train["attendance"][train["broadcasters"] == broadcasters_key[0]].values)/len(train["attendance"][train["broadcasters"] == broadcasters_key[0]].values)\nl =[]\na = []\nfor i in range(len(broadcasters_key)):\n    ave = sum(train["attendance"][train["broadcasters"] == broadcasters_key[i]].values)/len(train["attendance"][train["broadcasters"] == broadcasters_key[i]].values)\n    l.append(ave)\n    a.append(ave)\na.sort()\nbroad_t =[0]*len(l)\nfor i in range(len(l)):\n    broad_t[i] = a.index(l[i])\n\nfor i in range(len(l)):\n    train["broadcasters"][train["broadcasters"] == broadcasters_key[i]] = int(broad_t[i])\n    \ntrain.head()\n'

# %% [markdown]
# テストデータ前処理

# %%
test["match_date"] = [int(x.replace("-","")) for x in test["match_date"].values]
test["kick_off_time"] = [int(x.replace(":","")) for x in test["kick_off_time"].values]
test["section"] = [int(x.replace("第","").replace("節","")) for x in test["section"].values]
test["round"] = [int(x.replace("第","").replace("日","")) for x in test["round"].values]

# %%
for i in range(len(home_team_key)):
    test["home_team"][test["home_team"] == home_team_key[i]] = int(home_t[i])

test["home_team"][test["home_team"] == "長崎"] = -1    

for i in range(len(home_team_key)):
    test["away_team"][test["away_team"] == home_team_key[i]] = int(home_t[i])

test["away_team"][test["away_team"] == "長崎"] = -1 

for i in range(len(weather_key)):
    test["weather"][test["weather"] == weather_key[i]] = int(weather_t[i])  
test["weather"][test["weather"] == "曇晴"] = -1
test["weather"][test["weather"] == "曇のち霧"] = -2
test["weather"][test["weather"] == "雨のち曇のち雨"] = -3
test["weather"][test["weather"] == "曇時々雨のち曇"] = -4



for i in range(len(venue_key)):
    test["venue"][test["venue"] == venue_key[i]] = int(venue_t[i])

test["venue"][test["venue"] == "パナソニックスタジアム吹田"] = -1   
test["venue"][test["venue"] == "三協フロンテア柏スタジアム"] = -2
test["venue"][test["venue"] == "トランスコスモススタジアム長崎"] = -3   

for i in range(len(prefecture)):
    test["address"][test["address"] == prefecture[i]] = int(venue_i_t[i]) 

"""""   
for i in range(len(broadcasters_key)):
    test["broadcasters"][test["broadcasters"] == broadcasters_key[i]] = int(broad_t[i])

test["broadcasters"][test["broadcasters"] == "DAZN/テレビ神奈川/テレ玉"] = -1
test["broadcasters"][test["broadcasters"] == "DAZN/NHK仙台/NHK札幌"] = -2
test["broadcasters"][test["broadcasters"] == "DAZN/NHK総合"] = -3

"""""
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["home_team"][test["home_team"] == home_team_key[i]] = int(home_t[i])
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["home_team"][test["home_team"] == "長崎"] = -1
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["away_team"][test["away_team"] == home_team_key[i]] = int(home_t[i])
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["away_team"][test["away_team"] == "長崎"] = -1
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["weather"][test["weather"] == weather_key[i]] = int(weather_t[i])
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["weather"][test["weather"] == "曇晴"] = -1
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["weather"][test["weather"] == "曇のち霧"] = -2
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["weather"][test["weather"] == "雨のち曇のち雨"] = -3
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["weather"][test["weather"] == "曇時々雨のち曇"] = -4
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["venue"][test["venue"] == venue_key[i]] = int(venue_t[i])
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["venue"][test["venue"] == "パナソニックスタジアム吹田"] = -1
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["venue"][test["venue"] == "三協フロンテア柏スタジアム"] = -2
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["venue"][test["venue"] == "トランスコスモススタジアム長崎"] = -3
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/854783330.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["address"][test["address"] == prefecture[i]] = int(venue_i_t[i])
# '""   \nfor i in range(len(broadcasters_key)):\n    test["broadcasters"][test["broadcasters"] == broadcasters_key[i]] = int(broad_t[i])\n\ntest["broadcasters"][test["broadcasters"] == "DAZN/テレビ神奈川/テレ玉"] = -1\ntest["broadcasters"][test["broadcasters"] == "DAZN/NHK仙台/NHK札幌"] = -2\ntest["broadcasters"][test["broadcasters"] == "DAZN/NHK総合"] = -3\n\n'

# %% [markdown]
# 休日データ統合

# %%
holiday = pd.read_csv("holidays_in_japan.csv")

# %%
holiday["holiday_date"] = [int(x.replace("-","")) for x in holiday["holiday_date"].values]

# %%
holiday_key = sorted(set(holiday["holiday_date"].values.tolist()),key =holiday["holiday_date"].values.tolist().index)

# %%
train["holiday"]=0
test["holiday"] =0
for i in range(len(holiday_key)):
    train["holiday"][train["match_date"]==holiday_key[i]] = 1
    test["holiday"][test["match_date"]==holiday_key[i]] = 1
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1590965472.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["holiday"][train["match_date"]==holiday_key[i]] = 1
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1590965472.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["holiday"][test["match_date"]==holiday_key[i]] = 1

# %% [markdown]
# 試合詳細データ追加

# %%
match_r = pd.read_csv("match_reports.csv")
match_r.columns
match_c =['home_team_score','away_team_score']

# %%
train["home_team_score"]= 0
train["away_team_score"]= 0
test["home_team_score"]= 0
test["away_team_score"]= 0
match_r_key = sorted(set(match_r["id"].values.tolist()),key =match_r["id"].values.tolist().index)
for i in range(len(match_r_key)):
    train["home_team_score"][train["id"]==match_r_key[i]] = match_r["home_team_score"][i]
    train["away_team_score"][train["id"]==match_r_key[i]] = match_r["away_team_score"][i]
    test["home_team_score"][test["id"]==match_r_key[i]] = match_r["home_team_score"][i]
    test["away_team_score"][test["id"]==match_r_key[i]] = match_r["away_team_score"][i]
    
test.head()
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/3913748691.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["home_team_score"][train["id"]==match_r_key[i]] = match_r["home_team_score"][i]
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/3913748691.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["away_team_score"][train["id"]==match_r_key[i]] = match_r["away_team_score"][i]
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/3913748691.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["home_team_score"][test["id"]==match_r_key[i]] = match_r["home_team_score"][i]
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/3913748691.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["away_team_score"][test["id"]==match_r_key[i]] = match_r["away_team_score"][i]
#       id  match_date  kick_off_time  section  round home_team away_team venue  \
# 0  19075    20170225           1235        1      1        25        28    55
# 1  19076    20170225           1404        1      1        17         9    36
# 2  19077    20170225           1404        1      1        22        26    43
# 3  19078    20170225           1404        1      1        16        13    32
# 4  19079    20170225           1404        1      1        14        27    37
#
#   weather  temperature  humidity        broadcasters  capacity address  \
# 0      29         10.2      45.0     DAZN/テレビ神奈川/テレ玉     72081      42
# 1      26         10.6      36.0    DAZN/NHK仙台/NHK札幌     19694      29
# 2      29         10.1      63.0          DAZN/NHK総合     37496      37
# 3      29         15.0      40.0  DAZN/NHK BS1/テレビ静岡     20248      26
# 4      29         11.2      45.0    DAZN/NHK広島/NHK新潟     36894      24
#
#    holiday  home_team_score  away_team_score
# 0        0                3                2
# 1        0                1                0
# 2        0                0                1
# 3        0                0                1
# 4        0                1                1

# %% [markdown]
# スコア差

# %%
train["score_d"]=train["home_team_score"]-train["away_team_score"]
test["score_d"]=test["home_team_score"]-test["away_team_score"]

# %% [markdown]
# 勝敗

# %%
train["win"] = 0
test["win"] = 0
train["win"][train["score_d"]>0] = 1
train["win"][train["score_d"]<0] = -1
test["win"][test["score_d"]>0] = 1
test["win"][test["score_d"]<0] = -1
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/2061536963.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["win"][train["score_d"]>0] = 1
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/2061536963.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["win"][train["score_d"]<0] = -1
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/2061536963.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["win"][test["score_d"]>0] = 1
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/2061536963.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["win"][test["score_d"]<0] = -1

# %% [markdown]
# 勝ち負け率

# %%
train["win_rate"] = 0
test["win_rate"] = 0
for i in range(len(home_t)):
    h_w= sum(train["win"][train["home_team"]==home_t[i]])-sum(train["win"][train["away_team"]==home_t[i]])
    n = sum(train["home_team"][train["home_team"]==home_t[i]])-sum(train["home_team"][train["away_team"]==home_t[i]])
    train["win_rate"][train["home_team"]==home_t[i]] =h_w/n
    h_w= sum(test["win"][test["home_team"]==home_t[i]])-sum(test["win"][test["away_team"]==home_t[i]])
    n = sum(test["home_team"][test["home_team"]==home_t[i]])-sum(test["home_team"][test["away_team"]==home_t[i]])
    if n != 0:
        test["win_rate"][test["home_team"]==home_t[i]] =h_w/n
    else:
        test["win_rate"][test["home_team"]==home_t[i]] =0
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/2913444662.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["win_rate"][train["home_team"]==home_t[i]] =h_w/n
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/2913444662.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["win_rate"][test["home_team"]==home_t[i]] =h_w/n

# %%
train.head()
# Out:
#      id  match_date  kick_off_time  section  round home_team away_team venue  \
# 0  9190    20060304           1604        1      1        21        28    40
# 1  9191    20060305           1300        1      2         6        16    23
# 2  9192    20060305           1335        1      2        26        24    51
# 3  9193    20060305           1404        1      2        10         7    56
# 4  9194    20060305           1404        1      2        19        18    25
#
#   weather  temperature  ...                                broadcasters  \
# 0      29          8.3  ...                           NHK総合/J SPORTS(録)
# 1      29         12.9  ...                   山梨放送/テレビ静岡(録)/J SPORTS(録)
# 2      29         12.1  ...                   BS-i/MXテレビ(録)/J SPORTS(録)
# 3      29         11.6  ...                                    J SPORTS
# 4      29         13.1  ...  スカイパーフェクTV!/NHK名古屋(録)/NHK大阪(録)/J SPORTS(録)
#
#   attendance  capacity  address holiday  home_team_score  away_team_score  \
# 0      20916     21000       36       0                1                1
# 1      14277     15859        9       0                0                2
# 2      22531     48999       43       0                2                0
# 3      28564     51697       26       0                1                1
# 4      17199     20223       31       0                3                2
#
#    score_d  win  win_rate
# 0        0    0  0.098476
# 1       -2   -1  0.040657
# 2        2    1  0.008074
# 3        0    0  0.026575
# 4        1    1  0.059041
#
# [5 rows x 21 columns]

# %% [markdown]
# 型確認

# %%
train["home_team"]=train["home_team"].astype("int64")
train["away_team"]=train["away_team"].astype("int64")
train["venue"]=train["venue"].astype("int64")
train["weather"]=train["weather"].astype("int64")
train["address"]=train["address"].astype("int64")
train["temperature"]=train["temperature"].astype("float64")
#train["broadcasters"]=train["broadcasters"].astype("int64")

# %%
test["home_team"]=test["home_team"].astype("int64")
test["away_team"]=test["away_team"].astype("int64")
test["venue"]=test["venue"].astype("int64")
test["weather"]=test["weather"].astype("int64")
test["address"]=test["address"].astype("int64")
train["temperature"]=train["temperature"].astype("float64")
train["humidity"]=train["humidity"].astype("float64")

#test["broadcasters"]=test["broadcasters"].astype("int64")

# %%
display(train.info())
display(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3366 entries, 0 to 3365
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3366 non-null   int64
#  1   match_date       3366 non-null   int64
#  2   kick_off_time    3366 non-null   int64
#  3   section          3366 non-null   int64
#  4   round            3366 non-null   int64
#  5   home_team        3366 non-null   int64
#  6   away_team        3366 non-null   int64
#  7   venue            3366 non-null   int64
#  8   weather          3366 non-null   int64
#  9   temperature      3366 non-null   float64
#  10  humidity         3366 non-null   float64
#  11  broadcasters     3366 non-null   object
#  12  attendance       3366 non-null   int64
#  13  capacity         3366 non-null   int64
#  14  address          3366 non-null   int64
#  15  holiday          3366 non-null   int64
#  16  home_team_score  3366 non-null   int64
#  17  away_team_score  3366 non-null   int64
#  18  score_d          3366 non-null   int64
#  19  win              3366 non-null   int64
#  20  win_rate         3366 non-null   float64
# dtypes: float64(3), int64(17), object(1)
# memory usage: 552.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               459 non-null    int64
#  1   match_date       459 non-null    int64
#  2   kick_off_time    459 non-null    int64
#  3   section          459 non-null    int64
#  4   round            459 non-null    int64
#  5   home_team        459 non-null    int64
#  6   away_team        459 non-null    int64
#  7   venue            459 non-null    int64
#  8   weather          459 non-null    int64
#  9   temperature      459 non-null    float64
#  10  humidity         459 non-null    float64
#  11  broadcasters     459 non-null    object
#  12  capacity         459 non-null    int64
#  13  address          459 non-null    int64
#  14  holiday          459 non-null    int64
#  15  home_team_score  459 non-null    int64
#  16  away_team_score  459 non-null    int64
#  17  score_d          459 non-null    int64
#  18  win              459 non-null    int64
#  19  win_rate         459 non-null    float64
# dtypes: float64(3), int64(16), object(1)
# memory usage: 71.8+ KB
# None

# %% [markdown]
# 正規化

# %%
#train["temperature"] = (train["temperature"] - train["temperature"].mean()) / train["temperature"].std(ddof=0)
#test["temperature"] = (test["temperature"] - test["temperature"].mean()) / test["temperature"].std(ddof=0)

# %%
#train["humidity"] = (train["humidity"] - train["humidity"].mean()) / train["humidity"].std(ddof=0)
#test["humidity"] = (test["humidity"] - test["humidity"].mean()) / test["humidity"].std(ddof=0)

# %%
train["kick_off_time"] =((train["kick_off_time"] - 1700)%100)/60+(train["kick_off_time"] - 1700)//100
train["kick_off_time"] = (train["kick_off_time"] - train["kick_off_time"].mean()) / train["kick_off_time"].std(ddof=0)
test["kick_off_time"] =((test["kick_off_time"] - 1700)%100)/60+(test["kick_off_time"] - 1700)//100
test["kick_off_time"] = (test["kick_off_time"] - test["kick_off_time"].mean()) / test["kick_off_time"].std(ddof=0)

# %%
#train_std=train["attendance"].std(ddof=0)
#train_mean=train["attendance"].mean()
#train["attendance"] = (train["attendance"] - train["attendance"].mean()) / train["attendance"].std(ddof=0)

# %%
#train["capacity"] = (train["capacity"] - train["capacity"].mean()) / train["capacity"].std(ddof=0)
#test["capacity"] = (test["capacity"] - test["capacity"].mean()) / test["capacity"].std(ddof=0)

# %%
train.head()
# Out:
#      id  match_date  kick_off_time  section  round  home_team  away_team  \
# 0  9190    20060304      -0.270798        1      1         21         28
# 1  9191    20060305      -1.658459        1      2          6         16
# 2  9192    20060305      -1.394502        1      2         26         24
# 3  9193    20060305      -1.175794        1      2         10          7
# 4  9194    20060305      -1.175794        1      2         19         18
#
#    venue  weather  temperature  ...  \
# 0     40       29          8.3  ...
# 1     23       29         12.9  ...
# 2     51       29         12.1  ...
# 3     56       29         11.6  ...
# 4     25       29         13.1  ...
#
#                                  broadcasters attendance  capacity  address  \
# 0                           NHK総合/J SPORTS(録)      20916     21000       36
# 1                   山梨放送/テレビ静岡(録)/J SPORTS(録)      14277     15859        9
# 2                   BS-i/MXテレビ(録)/J SPORTS(録)      22531     48999       43
# 3                                    J SPORTS      28564     51697       26
# 4  スカイパーフェクTV!/NHK名古屋(録)/NHK大阪(録)/J SPORTS(録)      17199     20223       31
#
#    holiday  home_team_score  away_team_score  score_d  win  win_rate
# 0        0                1                1        0    0  0.098476
# 1        0                0                2       -2   -1  0.040657
# 2        0                2                0        2    1  0.008074
# 3        0                1                1        0    0  0.026575
# 4        0                3                2        1    1  0.059041
#
# [5 rows x 21 columns]

# %% [markdown]
# ターゲット最後に

# %%
first_column = train.pop('attendance')
l = len(train.columns.values)
train.insert(l,"attendance",first_column)

# %% [markdown]
# 相関行列

# %%
train.corr().style.background_gradient(axis=None,low=(1 + train.corr().values.min()) / (1 - train.corr().values.min()))
# Out:
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1601224467.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr().style.background_gradient(axis=None,low=(1 + train.corr().values.min()) / (1 - train.corr().values.min()))
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92579/1601224467.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr().style.background_gradient(axis=None,low=(1 + train.corr().values.min()) / (1 - train.corr().values.min()))
# <style type="text/css">
# #T_f1dc4_row0_col0, #T_f1dc4_row0_col1, #T_f1dc4_row1_col0, #T_f1dc4_row1_col1, #T_f1dc4_row2_col2, #T_f1dc4_row3_col3, #T_f1dc4_row4_col4, #T_f1dc4_row5_col5, #T_f1dc4_row6_col6, #T_f1dc4_row7_col7, #T_f1dc4_row8_col8, #T_f1dc4_row9_col9, #T_f1dc4_row10_col10, #T_f1dc4_row11_col11, #T_f1dc4_row12_col12, #T_f1dc4_row13_col13, #T_f1dc4_row14_col14, #T_f1dc4_row15_col15, #T_f1dc4_row16_col16, #T_f1dc4_row17_col17, #T_f1dc4_row18_col18, #T_f1dc4_row19_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col2, #T_f1dc4_row1_col2, #T_f1dc4_row1_col9, #T_f1dc4_row2_col0, #T_f1dc4_row2_col1, #T_f1dc4_row7_col14, #T_f1dc4_row7_col17, #T_f1dc4_row9_col1, #T_f1dc4_row12_col14, #T_f1dc4_row14_col7, #T_f1dc4_row14_col12, #T_f1dc4_row17_col7 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col3, #T_f1dc4_row3_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_f1dc4_row0_col4, #T_f1dc4_row1_col4, #T_f1dc4_row2_col19, #T_f1dc4_row4_col0, #T_f1dc4_row4_col1, #T_f1dc4_row19_col2 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col5, #T_f1dc4_row0_col6, #T_f1dc4_row0_col11, #T_f1dc4_row0_col16, #T_f1dc4_row1_col5, #T_f1dc4_row1_col6, #T_f1dc4_row1_col11, #T_f1dc4_row1_col16, #T_f1dc4_row1_col17, #T_f1dc4_row5_col0, #T_f1dc4_row5_col1, #T_f1dc4_row6_col0, #T_f1dc4_row6_col1, #T_f1dc4_row9_col11, #T_f1dc4_row11_col0, #T_f1dc4_row11_col1, #T_f1dc4_row11_col9, #T_f1dc4_row15_col19, #T_f1dc4_row16_col0, #T_f1dc4_row16_col1, #T_f1dc4_row17_col1, #T_f1dc4_row19_col15 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col7, #T_f1dc4_row0_col17, #T_f1dc4_row1_col7, #T_f1dc4_row2_col7, #T_f1dc4_row7_col0, #T_f1dc4_row7_col1, #T_f1dc4_row7_col2, #T_f1dc4_row7_col10, #T_f1dc4_row9_col19, #T_f1dc4_row10_col7, #T_f1dc4_row12_col15, #T_f1dc4_row15_col12, #T_f1dc4_row17_col0, #T_f1dc4_row19_col9 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col8, #T_f1dc4_row2_col6, #T_f1dc4_row2_col16, #T_f1dc4_row4_col9, #T_f1dc4_row4_col18, #T_f1dc4_row6_col2, #T_f1dc4_row8_col0, #T_f1dc4_row9_col4, #T_f1dc4_row9_col14, #T_f1dc4_row10_col17, #T_f1dc4_row14_col9, #T_f1dc4_row16_col2, #T_f1dc4_row16_col19, #T_f1dc4_row17_col10, #T_f1dc4_row18_col4, #T_f1dc4_row19_col16 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col9, #T_f1dc4_row9_col0, #T_f1dc4_row12_col16, #T_f1dc4_row16_col12 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col10, #T_f1dc4_row1_col8, #T_f1dc4_row2_col17, #T_f1dc4_row2_col18, #T_f1dc4_row3_col14, #T_f1dc4_row4_col17, #T_f1dc4_row6_col11, #T_f1dc4_row8_col1, #T_f1dc4_row9_col18, #T_f1dc4_row10_col0, #T_f1dc4_row10_col15, #T_f1dc4_row10_col16, #T_f1dc4_row11_col6, #T_f1dc4_row11_col17, #T_f1dc4_row14_col3, #T_f1dc4_row15_col10, #T_f1dc4_row16_col10, #T_f1dc4_row17_col2, #T_f1dc4_row17_col4, #T_f1dc4_row17_col11, #T_f1dc4_row17_col19, #T_f1dc4_row18_col2, #T_f1dc4_row18_col9, #T_f1dc4_row18_col19, #T_f1dc4_row19_col17, #T_f1dc4_row19_col18 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col12, #T_f1dc4_row1_col12, #T_f1dc4_row3_col13, #T_f1dc4_row5_col9, #T_f1dc4_row5_col10, #T_f1dc4_row6_col13, #T_f1dc4_row9_col5, #T_f1dc4_row10_col5, #T_f1dc4_row10_col12, #T_f1dc4_row12_col0, #T_f1dc4_row12_col1, #T_f1dc4_row12_col10, #T_f1dc4_row13_col3, #T_f1dc4_row13_col6, #T_f1dc4_row17_col18, #T_f1dc4_row18_col17 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col13, #T_f1dc4_row0_col15, #T_f1dc4_row1_col13, #T_f1dc4_row1_col15, #T_f1dc4_row2_col5, #T_f1dc4_row3_col7, #T_f1dc4_row3_col11, #T_f1dc4_row4_col7, #T_f1dc4_row4_col10, #T_f1dc4_row5_col2, #T_f1dc4_row7_col3, #T_f1dc4_row7_col4, #T_f1dc4_row8_col17, #T_f1dc4_row10_col4, #T_f1dc4_row11_col3, #T_f1dc4_row13_col0, #T_f1dc4_row13_col1, #T_f1dc4_row13_col14, #T_f1dc4_row13_col16, #T_f1dc4_row13_col17, #T_f1dc4_row14_col13, #T_f1dc4_row14_col15, #T_f1dc4_row14_col18, #T_f1dc4_row15_col0, #T_f1dc4_row15_col1, #T_f1dc4_row15_col14, #T_f1dc4_row16_col13, #T_f1dc4_row17_col8, #T_f1dc4_row17_col13, #T_f1dc4_row18_col14 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col14, #T_f1dc4_row0_col19, #T_f1dc4_row1_col14, #T_f1dc4_row1_col19, #T_f1dc4_row2_col11, #T_f1dc4_row5_col6, #T_f1dc4_row6_col5, #T_f1dc4_row10_col11, #T_f1dc4_row11_col2, #T_f1dc4_row11_col10, #T_f1dc4_row11_col15, #T_f1dc4_row14_col0, #T_f1dc4_row14_col1, #T_f1dc4_row15_col11, #T_f1dc4_row19_col0, #T_f1dc4_row19_col1 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_f1dc4_row0_col18, #T_f1dc4_row7_col15, #T_f1dc4_row15_col7, #T_f1dc4_row18_col0 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_f1dc4_row1_col3, #T_f1dc4_row3_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_f1dc4_row1_col10, #T_f1dc4_row3_col16, #T_f1dc4_row4_col14, #T_f1dc4_row4_col16, #T_f1dc4_row5_col13, #T_f1dc4_row7_col13, #T_f1dc4_row9_col15, #T_f1dc4_row10_col1, #T_f1dc4_row13_col5, #T_f1dc4_row13_col7, #T_f1dc4_row14_col4, #T_f1dc4_row14_col19, #T_f1dc4_row15_col9, #T_f1dc4_row15_col18, #T_f1dc4_row16_col3, #T_f1dc4_row16_col4, #T_f1dc4_row18_col15, #T_f1dc4_row19_col14 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_f1dc4_row1_col18, #T_f1dc4_row10_col18, #T_f1dc4_row18_col1, #T_f1dc4_row18_col10 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_f1dc4_row2_col3, #T_f1dc4_row3_col2, #T_f1dc4_row3_col5, #T_f1dc4_row3_col17, #T_f1dc4_row4_col6, #T_f1dc4_row4_col8, #T_f1dc4_row5_col3, #T_f1dc4_row6_col4, #T_f1dc4_row6_col7, #T_f1dc4_row6_col8, #T_f1dc4_row7_col6, #T_f1dc4_row8_col4, #T_f1dc4_row8_col6, #T_f1dc4_row8_col14, #T_f1dc4_row8_col15, #T_f1dc4_row9_col16, #T_f1dc4_row11_col13, #T_f1dc4_row11_col14, #T_f1dc4_row13_col11, #T_f1dc4_row14_col8, #T_f1dc4_row14_col11, #T_f1dc4_row15_col8, #T_f1dc4_row16_col9, #T_f1dc4_row17_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_f1dc4_row2_col4, #T_f1dc4_row2_col8, #T_f1dc4_row4_col2, #T_f1dc4_row4_col11, #T_f1dc4_row4_col15, #T_f1dc4_row6_col12, #T_f1dc4_row8_col2, #T_f1dc4_row9_col12, #T_f1dc4_row11_col4, #T_f1dc4_row12_col6, #T_f1dc4_row12_col9, #T_f1dc4_row15_col4, #T_f1dc4_row16_col18, #T_f1dc4_row18_col16 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_f1dc4_row2_col9, #T_f1dc4_row9_col2 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_f1dc4_row2_col10, #T_f1dc4_row10_col2, #T_f1dc4_row11_col12, #T_f1dc4_row12_col11 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_f1dc4_row2_col12, #T_f1dc4_row2_col15, #T_f1dc4_row3_col6, #T_f1dc4_row3_col12, #T_f1dc4_row3_col18, #T_f1dc4_row4_col12, #T_f1dc4_row4_col19, #T_f1dc4_row5_col18, #T_f1dc4_row6_col3, #T_f1dc4_row6_col9, #T_f1dc4_row6_col10, #T_f1dc4_row6_col18, #T_f1dc4_row7_col18, #T_f1dc4_row8_col16, #T_f1dc4_row8_col18, #T_f1dc4_row9_col6, #T_f1dc4_row9_col17, #T_f1dc4_row10_col6, #T_f1dc4_row12_col2, #T_f1dc4_row12_col3, #T_f1dc4_row12_col4, #T_f1dc4_row12_col13, #T_f1dc4_row13_col12, #T_f1dc4_row13_col15, #T_f1dc4_row15_col2, #T_f1dc4_row15_col13, #T_f1dc4_row16_col8, #T_f1dc4_row17_col9, #T_f1dc4_row18_col3, #T_f1dc4_row18_col5, #T_f1dc4_row18_col6, #T_f1dc4_row18_col7, #T_f1dc4_row18_col8, #T_f1dc4_row19_col4 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_f1dc4_row2_col13, #T_f1dc4_row6_col16, #T_f1dc4_row13_col2, #T_f1dc4_row16_col6 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_f1dc4_row2_col14, #T_f1dc4_row3_col19, #T_f1dc4_row11_col18, #T_f1dc4_row14_col2, #T_f1dc4_row18_col11, #T_f1dc4_row19_col3 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_f1dc4_row3_col4, #T_f1dc4_row4_col3, #T_f1dc4_row10_col19, #T_f1dc4_row19_col10 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_f1dc4_row3_col8, #T_f1dc4_row3_col15, #T_f1dc4_row4_col5, #T_f1dc4_row5_col4, #T_f1dc4_row8_col3, #T_f1dc4_row8_col12, #T_f1dc4_row12_col8, #T_f1dc4_row13_col18, #T_f1dc4_row15_col3, #T_f1dc4_row18_col13 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_f1dc4_row3_col9, #T_f1dc4_row7_col16, #T_f1dc4_row9_col3, #T_f1dc4_row16_col7 {
#   background-color: #

# %% [markdown]
# 学習データセット用意

# %%
# %%time
from tqdm import tqdm
import scipy.stats
import matplotlib.pyplot as plt 
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
# Out:
# CPU times: user 831 ms, sys: 1.06 s, total: 1.89 s
# Wall time: 1.21 s

# %%
c = train.columns.values

features = ['match_date', 'kick_off_time', 'section', 'round',
       'home_team', 'away_team', 'venue', 'weather', 'temperature',
       'humidity', 'holiday',"capacity","address","win_rate","home_team_score","away_team_score","score_d","win"]

#features = ['home_team', 'venue', 'weather', 'humidity', 'holiday',"capacity","address"]

y = train["attendance"]
X = train[features]
train_X, vali_X, train_y, vali_y = train_test_split(X, y,                # 訓練データとテストデータに分割する
                                                    test_size=0.3,       # テストデータの割合
                                                    shuffle=True,        # シャッフルする
                                                    random_state=0) 
                                                    
#train_y = train["attendance"]
#train_X = train[features]

# %%
from sklearn.linear_model    import LinearRegression
from sklearn.tree            import DecisionTreeRegressor
from sklearn.ensemble        import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics         import mean_squared_error

# %% [markdown]
# 重回帰

# %%
"""
lm = LinearRegression()
lm.fit(train_X, train_y)
y_pred2 = lm.predict(vali_X)
lm_mse = mean_squared_error(vali_y, y_pred2)
print('LinerRegression RMSE: ', np.sqrt(lm_mse))

coef_pd = pd.DataFrame(lm.coef_, columns=['coef'], index=features)

coef_pd.sort_values('coef', ascending=True)
"""
# Out:
# "\nlm = LinearRegression()\nlm.fit(train_X, train_y)\ny_pred2 = lm.predict(vali_X)\nlm_mse = mean_squared_error(vali_y, y_pred2)\nprint('LinerRegression RMSE: ', np.sqrt(lm_mse))\n\ncoef_pd = pd.DataFrame(lm.coef_, columns=['coef'], index=features)\n\ncoef_pd.sort_values('coef', ascending=True)\n"

# %%
test_X = test[features]
#test_y = lm.predict(test_X)

# %% [markdown]
# データファイル書き出し

# %%
import datetime
dt_now = datetime.datetime.now()
name=dt_now.strftime('%Y%m%d_%H%M')
file_name ="{}.csv".format(name)

# PassengerIdを取得
index = np.array(test["id"]).astype(int)
 
# my_prediction(予測データ）とPassengerIdをデータフレームへ落とし込む
my_solution = pd.DataFrame({'id': index, 'target': test_y})

# 書き出し
my_solution.to_csv(file_name,header=False,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 10
#       7 index = np.array(test["id"]).astype(int)
#       9 # my_prediction(予測データ）とPassengerIdをデータフレームへ落とし込む
# ---> 10 my_solution = pd.DataFrame({'id': index, 'target': test_y})
#      12 # 書き出し
#      13 my_solution.to_csv(file_name,header=False,index=False)
#
# NameError: name 'test_y' is not defined

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_validate
import xgboost as xgb
#import lightgbm as lgb

# %%
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train_X)
    rmse= np.sqrt(-cross_val_score(model, train_X, train_y, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %%
score = rmsle_cv(lasso)
print("Lasso score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Lasso score: 5822.9610 (1333.1898)

# %%
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# ElasticNet score: 5822.9364 (1333.1952)

# %%
score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# Kernel Ridge score: 5486.7626 (915.7975)

# %%
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Gradient Boosting score: 5639.3887 (521.6606)

# %%
score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# [01:39:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [01:39:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [01:39:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [01:39:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [01:39:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# Xgboost score: 5565.1316 (541.4107)

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)

# %%
averaged_models = AveragingModels(models = (ENet, GBoost, KRR, lasso))

score = rmsle_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
#  Averaged base models score: 5393.3293 (1111.8923)

# %%
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
averaged_models.fit(train_X, train_y)
averaged_train_pred = averaged_models.predict(train_X)
test_y_ave=averaged_models.predict(test_X)
averaged_pred = np.expm1(averaged_models.predict(test_X))
print(rmsle(train_y, averaged_train_pred))
# Out:
# /Users/takumu/VScode/.venv/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# 5095.504353406481
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92261/1166751417.py:4: RuntimeWarning: overflow encountered in expm1
#   averaged_pred = np.expm1(averaged_models.predict(test_X))

# %%
model_xgb.fit(train_X, train_y)
xgb_train_pred = model_xgb.predict(train_X)
test_y_xgb= model_xgb.predict(test_X)
xgb_pred = np.expm1(model_xgb.predict(test_X))
print(rmsle(train_y, xgb_train_pred))
# Out:
# [01:42:04] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# 4339.39072741903
# /var/folders/42/922wnzy13c1bxs6j8mf7gwq00000gn/T/ipykernel_92261/3603987873.py:4: RuntimeWarning: overflow encountered in expm1
#   xgb_pred = np.expm1(model_xgb.predict(test_X))

# %%
import datetime
dt_now = datetime.datetime.now()
name=dt_now.strftime('%Y%m%d_%H%M')
file_name ="{}.csv".format(name)

# PassengerIdを取得
index = np.array(test["id"]).astype(int)
 
# my_prediction(予測データ）とPassengerIdをデータフレームへ落とし込む
my_solution = pd.DataFrame({'id': index, 'target': test_y_ave})

# 書き出し
my_solution.to_csv(file_name,header=False,index=False)

# %% [markdown]
# ニューラルネットワーク
